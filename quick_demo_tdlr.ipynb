# %% [markdown]
# <a href="https://colab.research.google.com/github/yzhou359/MakeItTalk/blob/main/quick_demo_tdlr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MakeItTalk Quick Demo (natural human face animation)
#
# ## TDLR version
#
# Remember to change to GPU runtime first!

# %% [markdown]
# ## Preparation (run only once)

# %%
print('Git clone project and install requirements...')
# !git clone https://github.com/yzhou359/MakeItTalk
# Out:
# Git clone project and install requirements...
# fatal: destination path 'MakeItTalk' already exists and is not an empty directory.

# %%
print('Git clone project and install requirements...')
import os
# %cd MakeItTalk/

# !pip install -r requirements.txt
# !pip install tensorboardX

import sys
sys.path.append('/content/MakeItTalk')

os.makedirs('examples/dump', exist_ok=True)
os.makedirs('examples/ckpt', exist_ok=True)

# !pip install gdown
print('Done!')
print('Download pre-trained models...')
# !gdown -O examples/ckpt/ckpt_autovc.pth https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x
# !gdown -O examples/ckpt/ckpt_content_branch.pth https://drive.google.com/uc?id=1r3bfEvTVl6pCNw5xwUhEglwDHjWtAqQp
# !gdown -O examples/ckpt/ckpt_speaker_branch.pth https://drive.google.com/uc?id=1rV0jkyDqPW-aDJcj7xSO6Zt1zSXqn1mu
# !gdown -O examples/ckpt/ckpt_116_i2i_comb.pth https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a
# !gdown -O examples/dump/emb.pickle https://drive.google.com/uc?id=18-0CYl5E6ungS3H4rRSHjfYvvm-WwjTI
print('Done!')
# Out:
# Git clone project and install requirements...
# C:\Users\chakr\Downloads\pooja\MakeItTalk\MakeItTalk
# C:\Users\chakr\anaconda3\envs\py310\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Requirement already satisfied: ffmpeg-python in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: opencv-python in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 2)) (4.9.0.80)
# Requirement already satisfied: face_alignment in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: scikit-learn in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: pydub in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 5)) (0.25.1)
# Requirement already satisfied: pynormalize in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: soundfile in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: librosa in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 8)) (0.9.1)
# Requirement already satisfied: pysptk in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: pyworld in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 10)) (0.3.4)
# Requirement already satisfied: resemblyzer in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: future in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from ffmpeg-python->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from opencv-python->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: torch in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (2.2.0+cu121)
# Requirement already satisfied: scipy>=0.17 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (1.13.0)
# Requirement already satisfied: scikit-image in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (0.23.1)
# Requirement already satisfied: tqdm in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (4.66.2)
# Requirement already satisfied: numba in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (0.59.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: mutagen>=1.40.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from pynormalize->-r requirements.txt (line 6)) (1.47.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from soundfile->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa->-r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa->-r requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: pooch>=1.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa->-r requirements.txt (line 8)) (1.8.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa->-r requirements.txt (line 8)) (23.2)
# Requirement already satisfied: cython>=0.28.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from pysptk->-r requirements.txt (line 9)) (3.0.10)
# Requirement already satisfied: webrtcvad>=2.0.10 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from resemblyzer->-r requirements.txt (line 11)) (2.0.10)
# Requirement already satisfied: typing in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from resemblyzer->-r requirements.txt (line 11)) (3.7.4.3)
# Requirement already satisfied: pycparser in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 7)) (2.21)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from numba->face_alignment->-r requirements.txt (line 3)) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.31.0)
# Requirement already satisfied: filelock in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: sympy in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: jinja2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (2024.3.1)
# Requirement already satisfied: pillow>=9.1 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (10.3.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (2024.4.18)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: colorama in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from tqdm->face_alignment->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from jinja2->torch->face_alignment->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from sympy->torch->face_alignment->-r requirements.txt (line 3)) (1.3.0)
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)
# Requirement already satisfied: tensorboardX in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (2.6.2.2)
# Requirement already satisfied: numpy in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from tensorboardX) (23.2)
# Requirement already satisfied: protobuf>=3.20 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from tensorboardX) (4.25.3)
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)
# Requirement already satisfied: gdown in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from gdown) (3.13.4)
# Requirement already satisfied: requests[socks] in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests[socks]->gdown) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from tqdm->gdown) (0.4.6)
# Done!
# Download pre-trained models...
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)
# Downloading...
# From (original): https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x
# From (redirected): https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x&confirm=t&uuid=042731f0-24f3-4950-af87-eb3cb42d7557
# To: C:\Users\chakr\Downloads\pooja\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_autovc.pth
#
#   0%|          | 0.00/172M [00:00<?, ?B/s]
#   0%|          | 524k/172M [00:00<00:57, 2.98MB/s]
#   2%|1         | 3.15M/172M [00:00<00:13, 12.6MB/s]
#   4%|3         | 6.82M/172M [00:00<00:07, 21.7MB/s]
#   6%|6         | 10.5M/172M [00:00<00:06, 24.0MB/s]
#   8%|8         | 14.2M/172M [00:00<00:05, 27.2MB/s]
#  10%|#         | 17.8M/172M [00:00<00:05, 29.3MB/s]
#  12%|#2        | 21.0M/172M [00:00<00:05, 29.9MB/s]
#  14%|#4        | 24.6M/172M [00:00<00:04, 30.5MB/s]
#  16%|#6        | 27.8M/172M [00:01<00:04, 29.4MB/s]
#  18%|#8        | 31.5M/172M [00:01<00:04, 31.1MB/s]
#  20%|##        | 35.1M/172M [00:01<00:04, 31.0MB/s]
#  23%|##2       | 38.8M/172M [00:01<00:04, 31.4MB/s]
#  25%|##4       | 42.5M/172M [00:01<00:03, 32.5MB/s]
#  27%|##6       | 46.1M/172M [00:01<00:04, 27.0MB/s]
#  29%|##9       | 50.3M/172M [00:01<00:03, 30.5MB/s]
#  32%|###1      | 54.5M/172M [00:01<00:03, 32.5MB/s]
#  34%|###4      | 58.7M/172M [00:02<00:03, 34.7MB/s]
#  37%|###6      | 62.9M/172M [00:02<00:03, 35.3MB/s]
#  39%|###9      | 67.6M/172M [00:02<00:02, 36.5MB/s]
#  42%|####1     | 71.8M/172M [00:02<00:03, 30.8MB/s]
#  45%|####4     | 76.5M/172M [00:02<00:02, 33.4MB/s]
#  47%|####6     | 80.2M/172M [00:02<00:03, 30.2MB/s]
#  49%|####9     | 84.4M/172M [00:02<00:02, 31.6MB/s]
#  52%|#####1    | 89.1M/172M [00:02<00:02, 35.0MB/s]
#  55%|#####4    | 93.8M/172M [00:03<00:02, 37.6MB/s]
#  57%|#####7    | 98.0M/172M [00:03<00:01, 37.0MB/s]
#  59%|#####9    | 102M/172M [00:03<00:02, 26.6MB/s]
#  63%|######2   | 107M/172M [00:03<00:02, 31.9MB/s]
#  65%|######4   | 112M/172M [00:03<00:01, 33.7MB/s]
#  68%|######8   | 117M/172M [00:03<00:01, 37.4MB/s]
#  70%|#######   | 121M/172M [00:03<00:01, 29.3MB/s]
#  74%|#######3  | 126M/172M [00:04<00:01, 24.9MB/s]
#  76%|#######6  | 131M/172M [00:04<00:01, 28.4MB/s]
#  78%|#######8  | 135M/172M [00:04<00:01, 30.0MB/s]
#  81%|########1 | 139M/172M [00:04<00:00, 33.9MB/s]
#  84%|########3 | 144M/172M [00:04<00:00, 36.8MB/s]
#  87%|########6 | 149M/172M [00:04<00:00, 38.5MB/s]
#  89%|########9 | 153M/172M [00:04<00:00, 38.8MB/s]
#  92%|#########2| 158M/172M [00:04<00:00, 41.6MB/s]
#  95%|#########4| 163M/172M [00:05<00:00, 37.5MB/s]
#  98%|#########7| 168M/172M [00:05<00:00, 40.3MB/s]
# 100%|##########| 172M/172M [00:05<00:00, 32.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1r3bfEvTVl6pCNw5xwUhEglwDHjWtAqQp
# To: C:\Users\chakr\Downloads\pooja\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_content_branch.pth
#
#   0%|          | 0.00/7.88M [00:00<?, ?B/s]
#   7%|6         | 524k/7.88M [00:00<00:01, 4.58MB/s]
#  47%|####6     | 3.67M/7.88M [00:00<00:00, 19.0MB/s]
# 100%|#########9| 7.86M/7.88M [00:00<00:00, 29.0MB/s]
# 100%|##########| 7.88M/7.88M [00:00<00:00, 24.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rV0jkyDqPW-aDJcj7xSO6Zt1zSXqn1mu
# To: C:\Users\chakr\Downloads\pooja\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_speaker_branch.pth
#
#   0%|          | 0.00/15.4M [00:00<?, ?B/s]
#   3%|3         | 524k/15.4M [00:00<00:04, 3.62MB/s]
#  14%|#3        | 2.10M/15.4M [00:00<00:01, 8.73MB/s]
#  48%|####7     | 7.34M/15.4M [00:00<00:00, 24.2MB/s]
#  78%|#######8  | 12.1M/15.4M [00:00<00:00, 32.1MB/s]
# 100%|##########| 15.4M/15.4M [00:00<00:00, 27.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a
# From (redirected): https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a&confirm=t&uuid=afa9272c-7b87-4efc-8087-69bb8520a623
# To: C:\Users\chakr\Downloads\pooja\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_116_i2i_comb.pth
#
#   0%|          | 0.00/839M [00:00<?, ?B/s]
#   0%|          | 524k/839M [00:00<04:50, 2.88MB/s]
#   0%|          | 2.62M/839M [00:00<01:19, 10.5MB/s]
#   1%|          | 6.29M/839M [00:00<00:40, 20.3MB/s]
#   1%|1         | 10.5M/839M [00:00<00:29, 27.7MB/s]
#   2%|1         | 15.7M/839M [00:00<00:23, 35.3MB/s]
#   2%|2         | 20.4M/839M [00:00<00:21, 38.8MB/s]
#   3%|2         | 24.6M/839M [00:00<00:20, 38.9MB/s]
#   3%|3         | 28.8M/839M [00:00<00:20, 39.6MB/s]
#   4%|4         | 33.6M/839M [00:01<00:19, 40.8MB/s]
#   5%|4         | 38.3M/839M [00:01<00:19, 42.0MB/s]
#   5%|5         | 43.5M/839M [00:01<00:18, 43.9MB/s]
#   6%|5         | 48.2M/839M [00:01<00:18, 43.2MB/s]
#   6%|6         | 53.5M/839M [00:01<00:17, 44.2MB/s]
#   7%|7         | 58.7M/839M [00:01<00:17, 44.9MB/s]
#   8%|7         | 63.4M/839M [00:01<00:17, 44.2MB/s]
#   8%|8         | 68.7M/839M [00:01<00:16, 46.1MB/s]
#   9%|8         | 73.4M/839M [00:01<00:17, 44.3MB/s]
#   9%|9         | 78.1M/839M [00:02<00:17, 44.7MB/s]
#  10%|9         | 82.8M/839M [00:02<00:17, 44.4MB/s]
#  10%|#         | 87.6M/839M [00:02<00:17, 43.9MB/s]
#  11%|#1        | 92.8M/839M [00:02<00:16, 46.1MB/s]
#  12%|#1        | 97.5M/839M [00:02<00:16, 46.2MB/s]
#  12%|#2        | 102M/839M [00:02<00:15, 46.0MB/s]
#  13%|#2        | 107M/839M [00:02<00:15, 45.9MB/s]
#  13%|#3        | 112M/839M [00:02<00:16, 44.5MB/s]
#  14%|#3        | 117M/839M [00:02<00:15, 45.9MB/s]
#  15%|#4        | 122M/839M [00:02<00:17, 41.2MB/s]
#  15%|#5        | 126M/839M [00:03<00:17, 40.2MB/s]
#  16%|#5        | 132M/839M [00:03<00:18, 37.3MB/s]
#  17%|#6        | 140M/839M [00:03<00:14, 47.7MB/s]
#  17%|#7        | 145M/839M [00:03<00:15, 45.8MB/s]
#  18%|#7        | 150M/839M [00:03<00:14, 47.3MB/s]
#  19%|#8        | 156M/839M [00:03<00:14, 47.1MB/s]
#  19%|#9        | 161M/839M [00:03<00:14, 45.9MB/s]
#  20%|#9        | 166M/839M [00:03<00:14, 46.4MB/s]
#  20%|##        | 171M/839M [00:04<00:15, 44.5MB/s]
#  21%|##        | 176M/839M [00:04<00:15, 42.4MB/s]
#  22%|##1       | 180M/839M [00:04<00:15, 43.4MB/s]
#  22%|##2       | 185M/839M [00:04<00:15, 43.3MB/s]
#  23%|##2       | 190M/839M [00:04<00:15, 43.2MB/s]
#  23%|##3       | 196M/839M [00:04<00:14, 45.6MB/s]
#  24%|##3       | 200M/839M [00:04<00:14, 45.5MB/s]
#  24%|##4       | 205M/839M [00:04<00:13, 45.9MB/s]
#  25%|##5       | 210M/839M [00:04<00:13, 45.2MB/s]
#  26%|##5       | 214M/839M [00:05<00:13, 44.6MB/s]
#  26%|##6       | 220M/839M [00:05<00:13, 46.4MB/s]
#  27%|##6       | 224M/839M [00:05<00:19, 31.6MB/s]
#  27%|##7       | 229M/839M [00:05<00:18, 33.8MB/s]
#  28%|##7       | 234M/839M [00:05<00:16, 37.3MB/s]
#  29%|##8       | 240M/839M [00:05<00:14, 40.3MB/s]
#  29%|##9       | 244M/839M [00:05<00:14, 41.5MB/s]
#  30%|##9       | 250M/839M [00:05<00:13, 43.1MB/s]
#  30%|###       | 254M/839M [00:06<00:13, 42.4MB/s]
#  31%|###       | 260M/839M [00:06<00:12, 44.8MB/s]
#  32%|###1      | 264M/839M [00:06<00:12, 44.5MB/s]
#  32%|###2      | 269M/839M [00:06<00:13, 43.6MB/s]
#  33%|###2      | 274M/839M [00:06<00:12, 45.8MB/s]
#  33%|###3      | 279M/839M [00:06<00:12, 45.5MB/s]
#  34%|###3      | 284M/839M [00:06<00:12, 45.8MB/s]
#  34%|###4      | 288M/839M [00:06<00:11, 46.0MB/s]
#  35%|###4      | 293M/839M [00:06<00:12, 45.4MB/s]
#  36%|###5      | 298M/839M [00:07<00:12, 45.1MB/s]
#  36%|###6      | 303M/839M [00:07<00:11, 46.2MB/s]
#  37%|###6      | 308M/839M [00:07<00:11, 46.1MB/s]
#  37%|###7      | 312M/839M [00:07<00:11, 44.6MB/s]
#  38%|###7      | 318M/839M [00:07<00:11, 46.1MB/s]
#  38%|###8      | 322M/839M [00:07<00:11, 46.2MB/s]
#  39%|###9      | 327M/839M [00:07<00:11, 46.0MB/s]
#  40%|###9      | 332M/839M [00:07<00:11, 45.4MB/s]
#  40%|####      | 337M/839M [00:07<00:11, 44.9MB/s]
#  41%|####      | 341M/839M [00:08<00:13, 36.1MB/s]
#  41%|####1     | 347M/839M [00:08<00:12, 39.7MB/s]
#  42%|####1     | 351M/839M [00:08<00:13, 36.5MB/s]
#  42%|####2     | 356M/839M [00:08<00:12, 38.9MB/s]
#  43%|####2     | 360M/839M [00:08<00:12, 37.3MB/s]
#  44%|####3     | 365M/839M [00:08<00:12, 37.4MB/s]
#  44%|####4     | 369M/839M [00:08<00:16, 29.3MB/s]
#  45%|####4     | 375M/839M [00:09<00:13, 35.4MB/s]
#  45%|####5     | 379M/839M [00:09<00:13, 34.0MB/s]
#  46%|####5     | 383M/839M [00:09<00:13, 32.9MB/s]
#  46%|####6     | 387M/839M [00:09<00:13, 32.7MB/s]
#  47%|####6     | 391M/839M [00:09<00:13, 32.1MB/s]
#  47%|####7     | 394M/839M [00:09<00:14, 31.2MB/s]
#  47%|####7     | 398M/839M [00:09<00:14, 31.1MB/s]
#  48%|####7     | 402M/839M [00:09<00:14, 30.8MB/s]
#  48%|####8     | 405M/839M [00:09<00:14, 30.9MB/s]
#  49%|####8     | 408M/839M [00:10<00:14, 30.7MB/s]
#  49%|####9     | 411M/839M [00:10<00:13, 30.8MB/s]
#  50%|####9     | 415M/839M [00:10<00:13, 32.3MB/s]
#  50%|#####     | 421M/839M [00:10<00:10, 38.9MB/s]
#  51%|#####     | 425M/839M [00:10<00:10, 39.4MB/s]
#  51%|#####1    | 429M/839M [00:10<00:13, 29.6MB/s]
#  52%|#####2    | 439M/839M [00:10<00:09, 43.5MB/s]
#  53%|#####2    | 444M/839M [00:11<00:09, 41.5MB/s]
#  54%|#####3    | 449M/839M [00:11<00:08, 43.5MB/s]
#  54%|#####4    | 454M/839M [00:11<00:08, 43.3MB/s]
#  55%|#####4    | 459M/839M [00:11<00:08, 43.6MB/s]
#  55%|#####5    | 463M/839M [00:11<00:08, 42.6MB/s]
#  56%|#####5    | 468M/839M [00:11<00:08, 42.9MB/s]
#  56%|#####6    | 473M/839M [00:11<00:08, 43.2MB/s]
#  57%|#####6    | 478M/839M [00:11<00:08, 43.4MB/s]
#  58%|#####7    | 482M/839M [00:11<00:08, 43.2MB/s]
#  58%|#####8    | 487M/839M [00:11<00:08, 42.8MB/s]
#  59%|#####8    | 492M/839M [00:12<00:08, 41.4MB/s]
#  59%|#####9    | 497M/839M [00:12<00:07, 42.8MB/s]
#  60%|#####9    | 501M/839M [00:12<00:08, 40.9MB/s]
#  60%|######    | 506M/839M [00:12<00:07, 43.8MB/s]
#  61%|######    | 511M/839M [00:12<00:08, 40.9MB/s]
#  62%|######1   | 516M/839M [00:12<00:07, 43.0MB/s]
#  62%|######2   | 521M/839M [00:12<00:07, 43.4MB/s]
#  63%|######2   | 526M/839M [00:12<00:07, 43.4MB/s]
#  63%|######3   | 531M/839M [00:13<00:07, 43.9MB/s]
#  64%|######3   | 535M/839M [00:13<00:07, 43.0MB/s]
#  64%|######4   | 540M/839M [00:13<00:07, 42.5MB/s]
#  65%|######4   | 545M/839M [00:13<00:06, 42.5MB/s]
#  66%|######5   | 549M/839M [00:13<00:06, 43.4MB/s]
#  66%|######6   | 554M/839M [00:13<00:06, 42.3MB/s]
#  67%|######6   | 559M/839M [00:13<00:06, 43.9MB/s]
#  67%|######7   | 564M/839M [00:13<00:07, 35.7MB/s]
#  68%|######8   | 572M/839M [00:13<00:05, 46.0MB/s]
#  69%|######8   | 577M/839M [00:14<00:06, 42.8MB/s]
#  69%|######9   | 582M/839M [00:14<00:06, 38.2MB/s]
#  70%|######9   | 586M/839M [00:14<00:06, 36.4MB/s]
#  70%|#######   | 590M/839M [00:14<00:07, 34.5MB/s]
#  71%|#######   | 594M/839M [00:14<00:07, 33.0MB/s]
#  71%|#######1  | 598M/839M [00:14<00:07, 32.3MB/s]
#  72%|#######1  | 601M/839M [00:14<00:07, 32.6MB/s]
#  72%|#######2  | 605M/839M [00:15<00:07, 32.3MB/s]
#  73%|#######2  | 609M/839M [00:15<00:07, 31.7MB/s]
#  73%|#######3  | 612M/839M [00:15<00:07, 31.5MB/s]
#  73%|#######3  | 616M/839M [00:15<00:07, 31.1MB/s]
#  74%|#######3  | 619M/839M [00:15<00:07, 31.0MB/s]
#  74%|#######4  | 622M/839M [00:15<00:07, 30.3MB/s]
#  75%|#######4  | 626M/839M [00:15<00:06, 30.9MB/s]
#  75%|#######5  | 629M/839M [00:15<00:06, 30.9MB/s]
#  75%|#######5  | 633M/839M [00:15<00:06, 31.0MB/s]
#  76%|#######5  | 636M/839M [00:16<00:06, 30.9MB/s]
#  76%|#######6  | 640M/839M [00:16<00:05, 33.9MB/s]
#  77%|#######6  | 645M/839M [00:16<00:05, 38.3MB/s]
#  77%|#######7  | 650M/839M [00:16<00:05, 32.7MB/s]
#  78%|#######8  | 657M/839M [00:16<00:04, 41.4MB/s]
#  79%|#######9  | 663M/839M [00:16<00:03, 45.5MB/s]
#  80%|#######9  | 668M/839M [00:16<00:03, 44.5MB/s]
#  80%|########  | 673M/839M [00:16<00:03, 43.2MB/s]
#  81%|########  | 677M/839M [00:16<00:03, 42.1MB/s]
#  81%|########1 | 682M/839M [00:17<00:03, 40.9MB/s]
#  82%|########1 | 687M/839M [00:17<00:03, 41.6MB/s]
#  82%|########2 | 692M/839M [00:17<00:03, 41.6MB/s]
#  83%|########3 | 696M/839M [00:17<00:03, 42.7MB/s]
#  84%|########3 | 701M/839M [00:17<00:03, 42.2MB/s]
#  84%|########4 | 706M/839M [00:17<00:03, 43.1MB/s]
#  85%|########4 | 710M/839M [00:17<00:02, 42.8MB/s]
#  85%|########5 | 715M/839M [00:17<00:02, 42.7MB/s]
#  86%|########5 | 720M/839M [00:17<00:02, 43.0MB/s]
#  86%|########6 | 725M/839M [00:18<00:02, 42.6MB/s]
#  87%|########6 | 729M/839M [00:18<00:02, 43.2MB/s]
#  88%|########7 | 734M/839M [00:18<00:02, 43.3MB/s]
#  88%|########8 | 739M/839M [00:18<00:02, 43.5MB/s]
#  89%|########8 | 743M/839M [00:18<00:02, 44.1MB/s]
#  89%|########9 | 748M/839M [00:18<00:02, 44.0MB/s]
#  90%|########9 | 753M/839M [00:18<00:01, 44.2MB/s]
#  90%|######### | 758M/839M [00:18<00:02, 38.4MB/s]
#  91%|#########1| 764M/839M [00:19<00:01, 39.7MB/s]
#  92%|#########1| 771M/839M [00:19<00:01, 46.5MB/s]
#  93%|#########2| 776M/839M [00:19<00:01, 43.7MB/s]
#  93%|#########3| 781M/839M [00:19<00:01, 41.1MB/s]
#  94%|#########3| 786M/839M [00:19<00:01, 43.3MB/s]
#  94%|#########4| 791M/839M [00:19<00:01, 42.5MB/s]
#  95%|#########4| 796M/839M [00:19<00:01, 42.7MB/s]
#  95%|#########5| 801M/839M [00:19<00:00, 42.1MB/s]
#  96%|#########6| 805M/839M [00:19<00:00, 41.9MB/s]
#  97%|#########6| 810M/839M [00:20<00:00, 31.9MB/s]
#  97%|#########7| 815M/839M [00:20<00:00, 34.6MB/s]
#  98%|#########7| 819M/839M [00:20<00:00, 36.1MB/s]
#  98%|#########8| 823M/839M [00:20<00:00, 35.1MB/s]
#  99%|#########8| 827M/839M [00:20<00:00, 36.5MB/s]
#  99%|#########9| 832M/839M [00:20<00:00, 25.6MB/s]
# 100%|#########9| 836M/839M [00:21<00:00, 28.8MB/s]
# 100%|##########| 839M/839M [00:21<00:00, 39.7MB/s]
# Done!
# Downloading...
# From: https://drive.google.com/uc?id=18-0CYl5E6ungS3H4rRSHjfYvvm-WwjTI
# To: C:\Users\chakr\Downloads\pooja\MakeItTalk\MakeItTalk\examples\dump\emb.pickle
#
#   0%|          | 0.00/30.9M [00:00<?, ?B/s]
#   2%|1         | 524k/30.9M [00:00<00:09, 3.07MB/s]
#  10%|#         | 3.15M/30.9M [00:00<00:02, 12.9MB/s]
#  24%|##3       | 7.34M/30.9M [00:00<00:01, 23.2MB/s]
#  39%|###8      | 12.1M/30.9M [00:00<00:00, 29.3MB/s]
#  54%|#####4    | 16.8M/30.9M [00:00<00:00, 34.8MB/s]
#  71%|#######1  | 22.0M/30.9M [00:00<00:00, 37.4MB/s]
#  88%|########8 | 27.3M/30.9M [00:00<00:00, 41.7MB/s]
# 100%|##########| 30.9M/30.9M [00:00<00:00, 33.7MB/s]

# %% [markdown]
# ## Animate your photos here!
#
# - Upload your images to `examples` with size `256x256`. Or use existing ones.
#
# - Upload your speech audio files (could be many) to `examples`. Since it will process all `.wav` files under `examples`, remember to delete non-necessary `.wav` files. Or use an existing one `M6_04_16k.wav`.

# %% [markdown]
# ## Step 1/3: Choose your image (in below Dropdown).

# %%
import ipywidgets as widgets
import glob
import matplotlib.pyplot as plt
print("Choose the image name to animate: (saved in folder 'examples/')")
img_list = glob.glob1('examples', '*.jpg')
img_list.sort()
img_list = [item.split('.')[0] for item in img_list]
default_head_name = widgets.Dropdown(options=img_list, value='paint_boy')
def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        plt.imshow(plt.imread('examples/{}.jpg'.format(default_head_name.value)))
        plt.axis('off')
        plt.show()
default_head_name.observe(on_change)
display(default_head_name)
plt.imshow(plt.imread('examples/{}.jpg'.format(default_head_name.value)))
plt.axis('off')
plt.show()
# Out:
# Choose the image name to animate: (saved in folder 'examples/')
# Dropdown(index=41, options=('angelina', 'anne', 'anne2', 'audrey', 'aya', 'captain', 'captain2', 'cesi', 'chri…

# %% [markdown]
# ## Step 2/3: Setup your animation controllers (on right Sliders).

# %%
#@markdown # Animation Controllers
#@markdown Amplify the lip motion in horizontal direction
AMP_LIP_SHAPE_X = 2 #@param {type:"slider", min:0.5, max:5.0, step:0.1}

#@markdown Amplify the lip motion in vertical direction
AMP_LIP_SHAPE_Y = 2 #@param {type:"slider", min:0.5, max:5.0, step:0.1}

#@markdown Amplify the head pose motion (usually smaller than 1.0, put it to 0. for a static head pose)
AMP_HEAD_POSE_MOTION = 0.35 #@param {type:"slider", min:0.0, max:1.0, step:0.05}

#@markdown Add naive eye blink
ADD_NAIVE_EYE = True  #@param ["False", "True"] {type:"raw"}

#@markdown If your image has an opened mouth, put this as True, else False
CLOSE_INPUT_FACE_MOUTH = False  #@param ["False", "True"] {type:"raw"}          


#@markdown # Landmark Adjustment

#@markdown Adjust upper lip thickness (postive value means thicker)
UPPER_LIP_ADJUST = -1 #@param {type:"slider", min:-3.0, max:3.0, step:1.0}

#@markdown Adjust lower lip thickness (postive value means thicker)
LOWER_LIP_ADJUST = -1 #@param {type:"slider", min:-3.0, max:3.0, step:1.0}

#@markdown Adjust static lip width (in multipication)
LIP_WIDTH_ADJUST = 1.0 #@param {type:"slider", min:0.8, max:1.2, step:0.01}

# %%
# !pip uninstall librosa --yes
# !pip install librosa==0.9.1
# Out:
# Found existing installation: librosa 0.9.1
# Uninstalling librosa-0.9.1:
#   Successfully uninstalled librosa-0.9.1
# Collecting librosa==0.9.1
#   Using cached librosa-0.9.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (3.0.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (1.13.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (1.4.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (5.1.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (0.4.3)
# Requirement already satisfied: numba>=0.45.1 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (0.59.1)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (1.8.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from librosa==0.9.1) (23.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from numba>=0.45.1->librosa==0.9.1) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from pooch>=1.0->librosa==0.9.1) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from pooch>=1.0->librosa==0.9.1) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from scikit-learn>=0.19.1->librosa==0.9.1) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from soundfile>=0.10.2->librosa==0.9.1) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\envs\py310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2024.2.2)
# Using cached librosa-0.9.1-py3-none-any.whl (213 kB)
# Installing collected packages: librosa
# Successfully installed librosa-0.9.1
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\chakr\anaconda3\envs\py310\lib\site-packages)

# %% [markdown]
# ## Step 3/3: One-click to Run (just wait in seconds).

# %%
import sys
sys.path.append("thirdparty/AdaptiveWingLoss")
import os, glob
import numpy as np
import cv2
import argparse
from src.approaches.train_image_translation import Image_translation_block
import torch
import pickle
import face_alignment
from src.autovc.AutoVC_mel_Convertor_retrain_version import AutoVC_mel_Convertor
import shutil
import time
import util.utils as util
from scipy.signal import savgol_filter
from src.approaches.train_audio2landmark import Audio2landmark_model

sys.stdout = open(os.devnull, 'a')

parser = argparse.ArgumentParser()
parser.add_argument('--jpg', type=str, default='{}.jpg'.format(default_head_name.value))
parser.add_argument('--close_input_face_mouth', default=CLOSE_INPUT_FACE_MOUTH, action='store_true')
parser.add_argument('--load_AUTOVC_name', type=str, default='examples/ckpt/ckpt_autovc.pth')
parser.add_argument('--load_a2l_G_name', type=str, default='examples/ckpt/ckpt_speaker_branch.pth')
parser.add_argument('--load_a2l_C_name', type=str, default='examples/ckpt/ckpt_content_branch.pth') #ckpt_audio2landmark_c.pth')
parser.add_argument('--load_G_name', type=str, default='examples/ckpt/ckpt_116_i2i_comb.pth') #ckpt_image2image.pth') #ckpt_i2i_finetune_150.pth') #c
parser.add_argument('--amp_lip_x', type=float, default=AMP_LIP_SHAPE_X)
parser.add_argument('--amp_lip_y', type=float, default=AMP_LIP_SHAPE_Y)
parser.add_argument('--amp_pos', type=float, default=AMP_HEAD_POSE_MOTION)
parser.add_argument('--reuse_train_emb_list', type=str, nargs='+', default=[]) #  ['iWeklsXc0H8']) #['45hn7-LXDX8']) #['E_kmpT-EfOg']) #'iWeklsXc0H8', '29k8RtSUjE0', '45hn7-LXDX8',
parser.add_argument('--add_audio_in', default=False, action='store_true')
parser.add_argument('--comb_fan_awing', default=False, action='store_true')
parser.add_argument('--output_folder', type=str, default='examples')
parser.add_argument('--test_end2end', default=True, action='store_true')
parser.add_argument('--dump_dir', type=str, default='', help='')
parser.add_argument('--pos_dim', default=7, type=int)
parser.add_argument('--use_prior_net', default=True, action='store_true')
parser.add_argument('--transformer_d_model', default=32, type=int)
parser.add_argument('--transformer_N', default=2, type=int)
parser.add_argument('--transformer_heads', default=2, type=int)
parser.add_argument('--spk_emb_enc_size', default=16, type=int)
parser.add_argument('--init_content_encoder', type=str, default='')
parser.add_argument('--lr', type=float, default=1e-3, help='learning rate')
parser.add_argument('--reg_lr', type=float, default=1e-6, help='weight decay')
parser.add_argument('--write', default=False, action='store_true')
parser.add_argument('--segment_batch_size', type=int, default=1, help='batch size')
parser.add_argument('--emb_coef', default=3.0, type=float)
parser.add_argument('--lambda_laplacian_smooth_loss', default=1.0, type=float)
parser.add_argument('--use_11spk_only', default=False, action='store_true')
parser.add_argument('-f')
opt_parser = parser.parse_args()

img = cv2.imread('examples/' + opt_parser.jpg)
predictor = face_alignment.FaceAlignment(face_alignment.LandmarksType.THREE_D, device='cpu', flip_input=True)
shapes = predictor.get_landmarks(img)
if (not shapes or len(shapes) != 1):
    print('Cannot detect face landmarks. Exit.')
    exit(-1)
shape_3d = shapes[0]
if(opt_parser.close_input_face_mouth):
    util.close_input_face_mouth(shape_3d)
shape_3d[48:, 0] = (shape_3d[48:, 0] - np.mean(shape_3d[48:, 0])) * LIP_WIDTH_ADJUST + np.mean(shape_3d[48:, 0]) # wider lips
shape_3d[49:54, 1] -= UPPER_LIP_ADJUST           # thinner upper lip
shape_3d[55:60, 1] += LOWER_LIP_ADJUST           # thinner lower lip
shape_3d[[37,38,43,44], 1] -=2.    # larger eyes
shape_3d[[40,41,46,47], 1] +=2.    # larger eyes
shape_3d, scale, shift = util.norm_input_face(shape_3d)

print("Loaded Image...", file=sys.stderr)

au_data = []
au_emb = []
ains = glob.glob1('examples', '*.wav')
ains = [item for item in ains if item is not 'tmp.wav']
ains.sort()
for ain in ains:
    os.system('ffmpeg -y -loglevel error -i examples/{} -ar 16000 examples/tmp.wav'.format(ain))
    shutil.copyfile('examples/tmp.wav', 'examples/{}'.format(ain))

    # au embedding
    from thirdparty.resemblyer_util.speaker_emb import get_spk_emb
    me, ae = get_spk_emb('examples/{}'.format(ain))
    au_emb.append(me.reshape(-1))

    print('Processing audio file', ain)
    c = AutoVC_mel_Convertor('examples')

    au_data_i = c.convert_single_wav_to_autovc_input(audio_filename=os.path.join('examples', ain),
           autovc_model_path=opt_parser.load_AUTOVC_name)
    au_data += au_data_i
if(os.path.isfile('examples/tmp.wav')):
    os.remove('examples/tmp.wav')

print("Loaded audio...", file=sys.stderr)

# landmark fake placeholder
fl_data = []
rot_tran, rot_quat, anchor_t_shape = [], [], []
for au, info in au_data:
    au_length = au.shape[0]
    fl = np.zeros(shape=(au_length, 68 * 3))
    fl_data.append((fl, info))
    rot_tran.append(np.zeros(shape=(au_length, 3, 4)))
    rot_quat.append(np.zeros(shape=(au_length, 4)))
    anchor_t_shape.append(np.zeros(shape=(au_length, 68 * 3)))

if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_au.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_au.pickle'))
if (os.path.exists(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))

with open(os.path.join('examples', 'dump', 'random_val_fl.pickle'), 'wb') as fp:
    pickle.dump(fl_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_au.pickle'), 'wb') as fp:
    pickle.dump(au_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_gaze.pickle'), 'wb') as fp:
    gaze = {'rot_trans':rot_tran, 'rot_quat':rot_quat, 'anchor_t_shape':anchor_t_shape}
    pickle.dump(gaze, fp)

model = Audio2landmark_model(opt_parser, jpg_shape=shape_3d)
if(len(opt_parser.reuse_train_emb_list) == 0):
    model.test(au_emb=au_emb)
else:
    model.test(au_emb=None)

print("Audio->Landmark...", file=sys.stderr)

fls = glob.glob1('examples', 'pred_fls_*.txt')
fls.sort()

for i in range(0,len(fls)):
    fl = np.loadtxt(os.path.join('examples', fls[i])).reshape((-1, 68,3))
    fl[:, :, 0:2] = -fl[:, :, 0:2]
    fl[:, :, 0:2] = fl[:, :, 0:2] / scale - shift

    if (ADD_NAIVE_EYE):
        fl = util.add_naive_eye(fl)

    # additional smooth
    fl = fl.reshape((-1, 204))
    fl[:, :48 * 3] = savgol_filter(fl[:, :48 * 3], 15, 3, axis=0)
    fl[:, 48*3:] = savgol_filter(fl[:, 48*3:], 5, 3, axis=0)
    fl = fl.reshape((-1, 68, 3))

    ''' STEP 6: Imag2image translation '''
    model = Image_translation_block(opt_parser, single_test=True)
    with torch.no_grad():
        model.single_test(jpg=img, fls=fl, filename=fls[i], prefix=opt_parser.jpg.split('.')[0])
        print('finish image2image gen')
    os.remove(os.path.join('examples', fls[i]))

    print("{} / {}: Landmark->Face...".format(i+1, len(fls)), file=sys.stderr)
print("Done!", file=sys.stderr)
# Out:
# <>:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# Loaded Image...
# C:\Users\chakr\AppData\Local\Temp\ipykernel_14020\2995444083.py:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   ains = [item for item in ains if item is not 'tmp.wav']
# C:\Users\chakr\Downloads\pooja\MakeItTalk\src\autovc\retrain_version\vocoder_spec\extract_f0_func.py:97: FutureWarning: Pass sr=16000, n_fft=1024 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_basis = mel(16000, 1024, fmin=90, fmax=7600, n_mels=80).T
# Loaded audio...
# C:\Users\chakr\Downloads\pooja\MakeItTalk\src\approaches\train_audio2landmark.py:98: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   z = torch.tensor(torch.zeros(aus.shape[0], 128), requires_grad=False, dtype=torch.float).to(device)
# Audio->Landmark...
# 1 / 1: Landmark->Face...
# Done!

# %% [markdown]
# ## Visualize your animation!

# %%
from IPython.display import HTML
from base64 import b64encode

for ain in ains:
  OUTPUT_MP4_NAME = '{}_pred_fls_{}_audio_embed.mp4'.format(
    opt_parser.jpg.split('.')[0],
    ain.split('.')[0]
    )
  mp4 = open('examples/{}'.format(OUTPUT_MP4_NAME),'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

  print('Display animation: examples/{}'.format(OUTPUT_MP4_NAME), file=sys.stderr)
  display(HTML("""
  <video width=600 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
# Out:
# Display animation: examples/paint_boy_pred_fls_M6_04_16k_audio_embed.mp4
#   <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>
